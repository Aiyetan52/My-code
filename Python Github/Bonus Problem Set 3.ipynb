# %%
import sympy as sp
import sympy 
sympy.init_printing()
W_x,W_z,Y,X,Z,rho=sympy.symbols(('W_x','W_z','Y','X','Z','rho'))
X, Z = sp.var('X,Z',real=True);#Define the choice variables 
h= ((X**rho)+(Z**rho))-Y**rho #Demand Equation 
g= W_x*X+ W_z*Z  #Cost function i.e g=0
lam = sp.symbols('lambda', real = True) # the exchange rate variable of lagrangian multiplier
L = g - lam* h # lagrangian function
gradL = [sp.diff(L,c) for c in [X,Z]] # Gradient of Lagrangian w.r.t. (x,y)
KKT = gradL +[h] # Determine the Karush-Kuhn-Tucker(KKT) condition 
Sol= sp.solve(KKT, [X, Z, lam], dict=True) #minimize or maximize the U given g=0 by solving KKT conditions over F,Y Lambda
Sol
# Out:
# ⎡⎧                                                1
# ⎢⎪                                              ─────
# ⎢⎪                                              ρ - 1
# ⎢⎪   ⎛                                    1 - ρ⎞          ⎛
# ⎢⎪   ⎜                                    ─────⎟          ⎜
# ⎢⎪   ⎜                                      ρ  ⎟          ⎜
# ⎢⎨   ⎜   ⎛      -ρ   ⎛    ρ          ρ  ⎞⎞     ⎟          ⎜    ⎛      -ρ   ⎛
# ⎢⎪   ⎜   ⎜     ───── ⎜  ─────      ─────⎟⎟     ⎟          ⎜    ⎜     ───── ⎜
# ⎢⎪   ⎜   ⎜ -ρ  ρ - 1 ⎜  ρ - 1      ρ - 1⎟⎟     ⎟          ⎜    ⎜ -ρ  ρ - 1 ⎜
# ⎢⎪   ⎜Wₓ⋅⎝Y  ⋅ρ     ⋅⎝Wₓ      + W_z     ⎠⎠     ⎟          ⎜W_z⋅⎝Y  ⋅ρ     ⋅⎝Wₓ
# ⎢⎪X: ⎜─────────────────────────────────────────⎟     , Z: ⎜───────────────────
# ⎢⎪   ⎝                    ρ                    ⎠          ⎝
# ⎣⎩
#
#                           1                                             ⎫⎤
#                         ─────                                           ⎪⎥
# ...

# %%
X=(W_x*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Z=(W_z*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Y=((X**rho)+(Z**rho))**(1/rho)
Y
# Out:
#                _______________________________________________________________
#               ╱
#              ╱  ⎛                                                         1  ⎞
#             ╱   ⎜                                                       ─────⎟
#            ╱    ⎜                                                       ρ - 1⎟
#           ╱     ⎜⎛                                                1 - ρ⎞     ⎟
#          ╱      ⎜⎜                                                ─────⎟     ⎟
#         ╱       ⎜⎜                                                  ρ  ⎟     ⎟
#        ╱        ⎜⎜   ⎛  -ρ   ⎛    ρ          ρ  ⎞              -ρ⎞     ⎟     ⎟
#       ╱         ⎜⎜   ⎜ ───── ⎜  ─────      ─────⎟     _________  ⎟     ⎟     ⎟
#      ╱          ⎜⎜   ⎜ ρ - 1 ⎜  ρ - 1      ρ - 1⎟ rho╱  ρ    ρ   ⎟     ⎟     ⎟
#     ╱           ⎜⎜Wₓ⋅⎝ρ     ⋅⎝Wₓ      + W_z     ⎠⋅ ╲╱  X  + Z    ⎠     ⎟     ⎟
# rho╱            ⎜⎜─────────────────────────────────────────────────────⎟     ⎟
# ...

# %%
X=(W_x*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Z=(W_z*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
C= W_x*X+ W_z*Z
C
# Out:
#
#
#
#    ⎛
#    ⎜
#    ⎜
#    ⎜   ⎛
#    ⎜   ⎜                                           ___________________________
#    ⎜   ⎜                                          ╱
#    ⎜   ⎜                                         ╱  ⎛
#    ⎜   ⎜                                        ╱   ⎜
#    ⎜   ⎜                                       ╱    ⎜
#    ⎜   ⎜                                      ╱     ⎜⎛
#    ⎜   ⎜                                     ╱      ⎜⎜
#    ⎜   ⎜                                    ╱       ⎜⎜
#    ⎜   ⎜                                   ╱        ⎜⎜   ⎛  -ρ   ⎛    ρ
#    ⎜   ⎜  -ρ   ⎛    ρ          ρ  ⎞       ╱         ⎜⎜   ⎜ ───── ⎜  ─────
#    ⎜   ⎜ ───── ⎜  ─────      ─────⎟      ╱          ⎜⎜   ⎜ ρ - 1 ⎜  ρ - 1
#    ⎜   ⎜ ρ - 1 ⎜  ρ - 1      ρ - 1⎟     ╱           ⎜⎜Wₓ⋅⎝ρ     ⋅⎝Wₓ      + W_
#    ⎜Wₓ⋅⎜ρ     ⋅⎝Wₓ      + W_z     ⎠⋅rho╱            ⎜⎜────────────────────────
#    ⎜   ⎝                             ╲╱             ⎝⎝
# ...

# %%
from IPython.display import display
W_x=1
W_z=2
Y=100
rho=0.5
X=(W_x*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Z=(W_z*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
display(X)
display(Z)
# Out:
# 44.44444444444443
# 11.111111111111107

# %%
W_x=1
W_z=2
rho=0.5
X=44.44444444444443
Z=11.111111111111107
 
X=(W_x*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Z=(W_z*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Y=((X**rho)+(Z**rho))**(1/rho)
Y
# Out:
# 99.99999999999996

# %%
W_x=1
W_z=2
Y=100
rho=0.5
X=(W_x*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
Z=(W_z*(Y**(-rho)*rho**(-rho/(rho - 1))*(W_x**(rho/(rho - 1)) + W_z**(rho/(rho - 1))))**((1 - rho)/rho)/rho)**(1/(rho - 1))
C= W_x*X+ W_z*Z
C
# Out:
# 66.66666666666664
